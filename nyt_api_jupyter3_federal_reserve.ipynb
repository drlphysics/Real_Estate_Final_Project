# %%
import os
import time
import json
import pandas as pd
from datetime import datetime
import requests  # Ensure that the requests module is imported

# Constants for rate limits
REQUESTS_PER_MINUTE = 5
SECONDS_PER_REQUEST = 12
REQUESTS_PER_DAY = 500

# Function to generate a unique progress filename for each query
def get_progress_filename(query):
    # Remove any unwanted characters such as quotes and replace spaces with underscores
    query_safe = query.replace('"', '').replace("'", "").replace(' ', '_').lower()
    return f"nyt_progress_{query_safe}.json"

# Function to generate a unique CSV filename for each query
def get_csv_filename(query):
    # Remove any unwanted characters such as quotes and replace spaces with underscores
    query_safe = query.replace('"', '').replace("'", "").replace(' ', '_').lower()
    return f"nyt_{query_safe}_articles_20220101_20240731.csv"

# Save the progress to a unique file for each query
def save_progress(query, page, request_count):
    progress_filename = get_progress_filename(query)
    progress_data = {
        "query": query,
        "page": page,
        "request_count": request_count,
        "date": datetime.now().strftime('%Y-%m-%d')  # Save the current date
    }
    with open(progress_filename, "w") as f:
        json.dump(progress_data, f)
    print(f"Progress saved to {progress_filename}: {progress_data}")

# Load the progress from a unique file for each query
def load_progress(query):
    progress_filename = get_progress_filename(query)
    if not os.path.exists(progress_filename):
        print(f"No progress file found for query '{query}'. Starting from the beginning.")
        return None
    
    with open(progress_filename, "r") as f:
        progress_data = json.load(f)
        print(f"Progress loaded from {progress_filename}: {progress_data}")
        return progress_data

def get_nyt_article_count(api_key, query, begin_date=None, end_date=None):
    url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"
    
    params = {
        'q': query,
        'api-key': api_key,
        'begin_date': begin_date,
        'end_date': end_date,
        'page': 0,  # Only need to request the first page to get the count
    }

    response = requests.get(url, params=params)  # Use the requests module here
    response.raise_for_status()
    
    data = response.json()
    
    # Get the total number of articles from the 'meta' field
    total_articles = data['response']['meta']['hits']
    
    return total_articles

def get_nyt_articles(api_key, query, begin_date=None, end_date=None, page=0):
    url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"
    
    params = {
        'q': query,
        'api-key': api_key,
        'page': page,
        'begin_date': begin_date,
        'end_date': end_date,
    }

    response = requests.get(url, params=params)  # Use the requests module here
    response.raise_for_status()
    
    data = response.json()
    articles = data['response']['docs']
    
    return articles

def process_query(api_key, query, begin_date, end_date, request_count, max_requests_per_day, page=0):
    print(f"Processing query: {query} starting from page {page}")
    
    all_articles = []
    total_articles_fetched = 0  # Counter to track the total number of articles fetched
    
    # Generate the CSV filename for the query
    csv_filename = get_csv_filename(query)
    
    # Try loading existing data from the CSV file if it exists (to avoid overwriting)
    if os.path.exists(csv_filename):
        existing_df = pd.read_csv(csv_filename)
        all_articles = existing_df.to_dict('records')  # Convert to list of dicts
        total_articles_fetched = len(all_articles)  # Initialize counter with existing data
    
    while True:
        try:
            # Check if we've hit the daily request limit
            if request_count >= max_requests_per_day:
                print(f"Reached the daily request limit of {max_requests_per_day}. Stopping.")
                save_progress(query, page, request_count)
                # Save the data collected so far
                save_to_csv(all_articles, csv_filename)
                print(f"Total articles extracted so far: {total_articles_fetched}")
                return all_articles, request_count

            # Fetch articles for the current page
            articles = get_nyt_articles(api_key, query, begin_date, end_date, page=page)
            
            if not articles:
                break
            
            all_articles.extend(articles)
            total_articles_fetched += len(articles)  # Update the total articles counter
            print(f"Fetched {len(articles)} articles for this page, total so far: {total_articles_fetched}")
            
            page += 1
            request_count += 1  # Increment request count across queries
            
            # Save progress after every successful request
            save_progress(query, page, request_count)
            
            # Periodically save the data to the CSV file to ensure no data loss
            save_to_csv(all_articles, csv_filename)
            
            # Enforce rate limit: sleep for 12 seconds between requests
            time.sleep(SECONDS_PER_REQUEST)
        
        except requests.exceptions.HTTPError as e:
            if e.response.status_code == 429:
                print(f"Rate limit exceeded. Backing off...")
                time.sleep(60)
            else:
                raise
    
    # Final save after query is fully processed
    save_to_csv(all_articles, csv_filename)
    print(f"Total articles fetched for query '{query}': {total_articles_fetched}")
    
    # Create a unique DataFrame for the query
    query_df = create_dataframe(all_articles)
    
    return query_df, request_count

def create_dataframe(all_articles):
    # Convert the list of articles to a DataFrame
    data = {
        'Title': [article.get('headline', {}).get('main', 'No title available') for article in all_articles],
        'URL': [article.get('web_url', 'No URL available') for article in all_articles],
        'Lead Paragraph': [article.get('lead_paragraph', 'No content available') for article in all_articles],
        'Publication Date': [article.get('pub_date', 'No date available') for article in all_articles],
        'Source': [article.get('source', 'No source available') for article in all_articles],
    }

    nyt_extract_df = pd.DataFrame(data)
    
    return nyt_extract_df

def save_to_csv(all_articles, csv_filename):
    nyt_extract_df = create_dataframe(all_articles)
    
    # Save the DataFrame to CSV file
    nyt_extract_df.to_csv(csv_filename, index=False, encoding='utf-8')
    print(f"Data saved to {csv_filename}")

def main():
    # Your API key
    api_key = 'sample_api_key'  # Replace with your own API key
    
    # Define the date range
    begin_date = '20220101'  # Start date in YYYYMMDD format
    end_date = '20240731'    # End date in YYYYMMDD format
    
    # List of queries to process
    queries = ["federal reserve"]
    
    # Dictionary to store the DataFrame for each query
    query_dataframes = {}
    
    # Iterate over the queries
    for query in queries:
        # Load progress for the specific query
        progress = load_progress(query)
        if progress:
            last_query = progress['query']
            start_page = progress['page']
            request_count = progress['request_count']
            last_run_date = progress['date']
            
            # If a new day has started, reset the request count
            if last_run_date != datetime.now().strftime('%Y-%m-%d'):
                print("New day detected. Resetting the request count.")
                request_count = 0
                start_page = 0
        else:
            start_page = 0
            request_count = 0

        # Process the query and store the DataFrame in the dictionary
        query_df, request_count = process_query(api_key, query, begin_date, end_date, request_count, REQUESTS_PER_DAY, page=start_page)
        query_dataframes[query] = query_df
        
        # Display the DataFrame for the current query
        print(f"\nDataFrame for '{query}':")
        print(query_df.head())

    print("All queries have been processed.")

if __name__ == "__main__":
    main()
# Out:
# Progress loaded from nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 27, 'request_count': 27, 'date': '2024-08-19'}
# Processing query: federal reserve starting from page 27
# Fetched 10 articles for this page, total so far: 4290
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 28, 'request_count': 28, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4300
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 29, 'request_count': 29, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4310
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 30, 'request_count': 30, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4320
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 31, 'request_count': 31, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4330
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 32, 'request_count': 32, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4340
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 33, 'request_count': 33, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4350
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 34, 'request_count': 34, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4360
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 35, 'request_count': 35, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4370
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 36, 'request_count': 36, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4380
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 37, 'request_count': 37, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4390
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 38, 'request_count': 38, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4400
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 39, 'request_count': 39, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4410
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 40, 'request_count': 40, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4420
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 41, 'request_count': 41, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4430
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 42, 'request_count': 42, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4440
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 43, 'request_count': 43, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4450
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 44, 'request_count': 44, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4460
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 45, 'request_count': 45, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4470
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 46, 'request_count': 46, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4480
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 47, 'request_count': 47, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4490
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 48, 'request_count': 48, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4500
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 49, 'request_count': 49, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4510
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 50, 'request_count': 50, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4520
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 51, 'request_count': 51, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4530
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 52, 'request_count': 52, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4540
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 53, 'request_count': 53, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4550
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 54, 'request_count': 54, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4560
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 55, 'request_count': 55, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4570
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 56, 'request_count': 56, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4580
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 57, 'request_count': 57, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 4590
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 58, 'request_count': 58, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 4600
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page':
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 158, 'request_count': 158, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5600
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 159, 'request_count': 159, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5610
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 160, 'request_count': 160, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5620
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 161, 'request_count': 161, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5630
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 162, 'request_count': 162, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5640
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 163, 'request_count': 163, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5650
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 164, 'request_count': 164, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5660
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 165, 'request_count': 165, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5670
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 166, 'request_count': 166, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5680
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 167, 'request_count': 167, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5690
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 168, 'request_count': 168, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5700
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 169, 'request_count': 169, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5710
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 170, 'request_count': 170, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5720
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 171, 'request_count': 171, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5730
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 172, 'request_count': 172, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5740
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 173, 'request_count': 173, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5750
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 174, 'request_count': 174, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5760
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 175, 'request_count': 175, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5770
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 176, 'request_count': 176, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5780
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 177, 'request_count': 177, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5790
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 178, 'request_count': 178, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5800
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 179, 'request_count': 179, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5810
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 180, 'request_count': 180, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5820
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 181, 'request_count': 181, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5830
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 182, 'request_count': 182, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5840
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 183, 'request_count': 183, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5850
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 184, 'request_count': 184, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5860
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 185, 'request_count': 185, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5870
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 186, 'request_count': 186, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5880
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 187, 'request_count': 187, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5890
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 188, 'request_count': 188, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5900
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 189, 'request_count': 189, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5910
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 190, 'request_count': 190, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5920
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 191, 'request_count': 191, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5930
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 192, 'request_count': 192, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5940
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 193, 'request_count': 193, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5950
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 194, 'request_count': 194, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5960
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 195, 'request_count': 195, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5970
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 196, 'request_count': 196, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 5980
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 197, 'request_count': 197, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 5990
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 198, 'request_count': 198, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Fetched 10 articles for this page, total so far: 6000
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 199, 'request_count': 199, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 6010
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 200, 'request_count': 200, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Fetched 10 articles for this page, total so far: 6020
# Progress saved to nyt_progress_federal_reserve.json: {'query': 'federal reserve', 'page': 201, 'request_count': 201, 'date': '2024-08-19'}
# Data saved to nyt_federal_reserve_articles_20220101_20240731.csv
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# Rate limit exceeded. Backing off...
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connection.py:203, in HTTPConnection._new_conn(self)
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:492, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     491         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 492     raise new_e
#     494 # conn.request() calls http.client.*.request, not the method in
#     495 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     467 try:
# --> 468     self._validate_conn(conn)
#     469 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connection.py:611, in HTTPSConnection.connect(self)
#     610 sock: socket.socket | ssl.SSLSocket
# --> 611 self.sock = sock = self._new_conn()
#     612 server_hostname: str = self.host
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connection.py:210, in HTTPConnection._new_conn(self)
#     209 except socket.gaierror as e:
# --> 210     raise NameResolutionError(self.host, self, e) from e
#     211 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x000001A3AB166E00>: Failed to resolve 'api.nytimes.com' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\urllib3\util\retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.nytimes.com', port=443): Max retries exceeded with url: /svc/search/v2/articlesearch.json?q=federal+reserve&api-key=S03RGAvnZiFYKcIbnpeXqSbN41PaxHuU&page=201&begin_date=20220101&end_date=20240731 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001A3AB166E00>: Failed to resolve 'api.nytimes.com' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 219
#     216     print("All queries have been processed.")
#     218 if __name__ == "__main__":
# --> 219     main()
#
# Cell In[3], line 209, in main()
#     206     request_count = 0
#     208 # Process the query and store the DataFrame in the dictionary
# --> 209 query_df, request_count = process_query(api_key, query, begin_date, end_date, request_count, REQUESTS_PER_DAY, page=start_page)
#     210 query_dataframes[query] = query_df
#     212 # Display the DataFrame for the current query
#
# Cell In[3], line 117, in process_query(api_key, query, begin_date, end_date, request_count, max_requests_per_day, page)
#     114     return all_articles, request_count
#     116 # Fetch articles for the current page
# --> 117 articles = get_nyt_articles(api_key, query, begin_date, end_date, page=page)
#     119 if not articles:
#     120     break
#
# Cell In[3], line 82, in get_nyt_articles(api_key, query, begin_date, end_date, page)
#      72 url = "https://api.nytimes.com/svc/search/v2/articlesearch.json"
#      74 params = {
#      75     'q': query,
#      76     'api-key': api_key,
#    (...)
#      79     'end_date': end_date,
#      80 }
# ---> 82 response = requests.get(url, params=params)  # Use the requests module here
#      83 response.raise_for_status()
#      85 data = response.json()
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\KURTD\anaconda3\envs\dev\lib\site-packages\requests\adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='api.nytimes.com', port=443): Max retries exceeded with url: /svc/search/v2/articlesearch.json?q=federal+reserve&api-key=S03RGAvnZiFYKcIbnpeXqSbN41PaxHuU&page=201&begin_date=20220101&end_date=20240731 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001A3AB166E00>: Failed to resolve 'api.nytimes.com' ([Errno 11001] getaddrinfo failed)"))
